# %%
import numpy as np
import pandas as pd
import matplotlib as plt

# %%
datos=pd.Categorical(["Uno","Dos","C","D","E","F"])

# %%
datos
# Out:
# [Uno, Dos, C, D, E, F]
# Categories (6, object): [C, D, Dos, E, F, Uno]

# %%
ts=pd.Series(np.random.randn(1000), index=pd.date_range("1/1/2019", periods=1000))

# %%
df=pd.DataFrame(np.random.randn(1000,4), index=ts.index, columns=list("ABCD"))
df = df.cumsum()
df.plot()

# %%
i.apply(np.cumsum)
# Out:
#     A   B
# 0   3   4
# 1   6   8
# 2   9  12
# 3  12  16

# %%
df = pd.DataFrame(np.random.rand(6,6), index=datos, columns=list("ABCDEF"))

# %%
df
# Out:
#             A         B         C         D         E         F
# Uno  0.398138  0.623543  0.243279  0.528753  0.938794  0.064821
# Dos  0.345528  0.212651  0.413287  0.360768  0.025789  0.555231
# C    0.990423  0.872757  0.193527  0.824328  0.510967  0.904035
# D    0.116341  0.736788  0.484949  0.480331  0.963614  0.823530
# E    0.471687  0.964213  0.388622  0.262274  0.372822  0.718940
# F    0.924365  0.347553  0.449584  0.239665  0.776671  0.359602

# %%
df10=pd.DataFrame({"A":pd.array([3] * 4),
                  "F":"Foo",
                  "B":pd.array([2] * 4)})

# %%
df10
# Out:
#    A    F  B
# 0  3  Foo  2
# 1  3  Foo  2
# 2  3  Foo  2
# 3  3  Foo  2

# %%
df20=pd.DataFrame(np.random.rand(6,6))

# %%
df20
# Out:
#           0         1         2         3         4         5
# 0  0.198677  0.107073  0.607820  0.830130  0.897775  0.575047
# 1  0.543003  0.344049  0.105433  0.797008  0.017993  0.013760
# 2  0.243564  0.454440  0.046634  0.656596  0.019814  0.397079
# 3  0.372800  0.980315  0.115889  0.033044  0.020484  0.765580
# 4  0.531584  0.381779  0.304386  0.838371  0.689797  0.584176
# 5  0.282536  0.678797  0.224798  0.497574  0.500438  0.378372

# %%
df21=np.copy(df20)

# %%
df20.tail(3)
# Out:
#           0         1         2         3         4         5
# 3  0.372800  0.980315  0.115889  0.033044  0.020484  0.765580
# 4  0.531584  0.381779  0.304386  0.838371  0.689797  0.584176
# 5  0.282536  0.678797  0.224798  0.497574  0.500438  0.378372

# %%
df20.index
# Out:
# RangeIndex(start=0, stop=6, step=1)

# %%
type(df21)
# Out:
# numpy.ndarray

# %%
df20.index
# Out:
# RangeIndex(start=0, stop=6, step=1)

# %%
df20.describe()
# Out:
#               0         1         2         3         4         5
# count  6.000000  6.000000  6.000000  6.000000  6.000000  6.000000
# mean   0.362027  0.491075  0.234160  0.608787  0.357717  0.452336
# std    0.147413  0.302310  0.205117  0.310890  0.391312  0.257462
# min    0.198677  0.107073  0.046634  0.033044  0.017993  0.013760
# 25%    0.253307  0.353482  0.108047  0.537329  0.019981  0.383049
# 50%    0.327668  0.418109  0.170343  0.726802  0.260461  0.486063
# 75%    0.491888  0.622708  0.284489  0.821849  0.642457  0.581894
# max    0.543003  0.980315  0.607820  0.838371  0.897775  0.765580

# %%
df20.T
# Out:
#           0         1         2         3         4         5
# 0  0.198677  0.543003  0.243564  0.372800  0.531584  0.282536
# 1  0.107073  0.344049  0.454440  0.980315  0.381779  0.678797
# 2  0.607820  0.105433  0.046634  0.115889  0.304386  0.224798
# 3  0.830130  0.797008  0.656596  0.033044  0.838371  0.497574
# 4  0.897775  0.017993  0.019814  0.020484  0.689797  0.500438
# 5  0.575047  0.013760  0.397079  0.765580  0.584176  0.378372

# %%
df20
# Out:
#           0         1         2         3         4         5
# 0  0.198677  0.107073  0.607820  0.830130  0.897775  0.575047
# 1  0.543003  0.344049  0.105433  0.797008  0.017993  0.013760
# 2  0.243564  0.454440  0.046634  0.656596  0.019814  0.397079
# 3  0.372800  0.980315  0.115889  0.033044  0.020484  0.765580
# 4  0.531584  0.381779  0.304386  0.838371  0.689797  0.584176
# 5  0.282536  0.678797  0.224798  0.497574  0.500438  0.378372

# %%
df
# Out:
#             A         B         C         D         E         F
# Uno  0.398138  0.623543  0.243279  0.528753  0.938794  0.064821
# Dos  0.345528  0.212651  0.413287  0.360768  0.025789  0.555231
# C    0.990423  0.872757  0.193527  0.824328  0.510967  0.904035
# D    0.116341  0.736788  0.484949  0.480331  0.963614  0.823530
# E    0.471687  0.964213  0.388622  0.262274  0.372822  0.718940
# F    0.924365  0.347553  0.449584  0.239665  0.776671  0.359602

# %%
df30=df.copy()

# %%
df30
# Out:
#             A         B         C         D         E         F
# Uno  0.398138  0.623543  0.243279  0.528753  0.938794  0.064821
# Dos  0.345528  0.212651  0.413287  0.360768  0.025789  0.555231
# C    0.990423  0.872757  0.193527  0.824328  0.510967  0.904035
# D    0.116341  0.736788  0.484949  0.480331  0.963614  0.823530
# E    0.471687  0.964213  0.388622  0.262274  0.372822  0.718940
# F    0.924365  0.347553  0.449584  0.239665  0.776671  0.359602

# %%
ab=pd.date_range("20190101", periods=10)

# %%
ab
# Out:
# DatetimeIndex(['2019-01-01', '2019-01-02', '2019-01-03', '2019-01-04',
#                '2019-01-05', '2019-01-06', '2019-01-07', '2019-01-08',
#                '2019-01-09', '2019-01-10'],
#               dtype='datetime64[ns]', freq='D')

# %%
ab.dtype
# Out:
# dtype('<M8[ns]')

# %%
aa = pd.DataFrame({"A":pd.date_range("2013",periods=10),
                  "B":pd.date_range("2014",periods=10),
                  "C":pd.date_range("2015",periods=10),
                  "D":pd.date_range("2016",periods=10)})

# %%
aa.dtypes
# Out:
# A    datetime64[ns]
# B    datetime64[ns]
# C    datetime64[ns]
# D    datetime64[ns]
# dtype: object

# %%
aa
# Out:
#            A          B          C          D
# 0 2013-01-01 2014-01-01 2015-01-01 2016-01-01
# 1 2013-01-02 2014-01-02 2015-01-02 2016-01-02
# 2 2013-01-03 2014-01-03 2015-01-03 2016-01-03
# 3 2013-01-04 2014-01-04 2015-01-04 2016-01-04
# 4 2013-01-05 2014-01-05 2015-01-05 2016-01-05
# 5 2013-01-06 2014-01-06 2015-01-06 2016-01-06
# 6 2013-01-07 2014-01-07 2015-01-07 2016-01-07
# 7 2013-01-08 2014-01-08 2015-01-08 2016-01-08
# 8 2013-01-09 2014-01-09 2015-01-09 2016-01-09
# 9 2013-01-10 2014-01-10 2015-01-10 2016-01-10

# %%
aa.loc[ : ,"C"] = np.array([5] * len(aa))

# %%
aa
# Out:
#            A          B  C          D
# 0 2013-01-01 2014-01-01  5 2016-01-01
# 1 2013-01-02 2014-01-02  5 2016-01-02
# 2 2013-01-03 2014-01-03  5 2016-01-03
# 3 2013-01-04 2014-01-04  5 2016-01-04
# 4 2013-01-05 2014-01-05  5 2016-01-05
# 5 2013-01-06 2014-01-06  5 2016-01-06
# 6 2013-01-07 2014-01-07  5 2016-01-07
# 7 2013-01-08 2014-01-08  5 2016-01-08
# 8 2013-01-09 2014-01-09  5 2016-01-09
# 9 2013-01-10 2014-01-10  5 2016-01-10

# %%
aa.iat[0,0]="20130101"
aa
# Out:
#                               A          B  C          D
# 0 2151-06-04 06:32:39.009206272 2014-01-01  5 2016-01-01
# 1 2013-01-02 00:00:00.000000000 2014-01-02  5 2016-01-02
# 2 2013-01-03 00:00:00.000000000 2014-01-03  5 2016-01-03
# 3 2013-01-04 00:00:00.000000000 2014-01-04  5 2016-01-04
# 4 2013-01-05 00:00:00.000000000 2014-01-05  5 2016-01-05
# 5 2013-01-06 00:00:00.000000000 2014-01-06  5 2016-01-06
# 6 2013-01-07 00:00:00.000000000 2014-01-07  5 2016-01-07
# 7 2013-01-08 00:00:00.000000000 2014-01-08  5 2016-01-08
# 8 2013-01-09 00:00:00.000000000 2014-01-09  5 2016-01-09
# 9 2013-01-10 00:00:00.000000000 2014-01-10  5 2016-01-10

# %%
a=
# Out:
#   File "<ipython-input-33-2d920c342ece>", line 1
#     a=
#       ^
# SyntaxError: invalid syntax
